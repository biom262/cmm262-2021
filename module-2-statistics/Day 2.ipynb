# %% [markdown]
# # Day 2: Choosing the Right Statistical Test
# <img src="attachment:34a0eb16-e002-4cc7-8b44-923354791f72.png" width="800px">
#
# ># Goals
# > 1. Hypothesis Testing
# > 2. Types of Variables
# > 3. Types of Tests
# > 4. Choosing the Right Test

# %% [markdown]
# # 1. Hypothesis testing
#
# You may have an idea, prediction, or theory that you want to explore. Hypothesis testing is a process to **quantitatively** investigate your hypotheses.
#
# Null hypothesis vs alternative hypothesis
#
# $H_0$: Adelie penguins do not have smaller flippers than chinstrap penguins.
#
# $H_a$: Adelie penguins have smaller flippers than chinstrap penguins.

# %% [markdown]
# https://www.inferentialthinking.com/chapters/15/1/Correlation.html
# correlations, association is not causation, correlation measure linear association, correlation is affected by outliers
#
# http://www.tylervigen.com/spurious-correlations

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
sns.pairplot(penguins, hue='species')

# %%
sns.displot(data=penguins, x='flipper_length_mm', hue='species', kind='kde', fill=True)

# %%
adelie = penguins.loc[penguins['species'] == 'Adelie']
chinstrap = penguins.loc[penguins['species'] == 'Chinstrap']
gentoo = penguins.loc[penguins['species'] == 'Gentoo']

# %% [markdown]
# # One sample t-test

# %%
adelie
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # Independent samples t-test

# %% [markdown]
# # Paired sample t-test
